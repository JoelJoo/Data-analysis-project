# %% [markdown]
# INDEXING IN PANDAS

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:/Data analysis freeCodeCamp/archive_3/Salary Prediction of Data Professions.csv", index_col = "SALARY")
df
# Out:
#        FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION  \
# SALARY
# 44570      TOMASA       ARMEN   F   5-18-2014   01-07-2016         Analyst
# 89207       ANNIE         NaN   F         NaN   01-07-2016       Associate
# 40955       OLIVE        ANCY   F   7-28-2014   01-07-2016         Analyst
# 45550      CHERRY     AQUILAR   F  04-03-2013   01-07-2016         Analyst
# 43161        LEON  ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst
# ...           ...         ...  ..         ...          ...             ...
# 185977  KATHERINE      ALSDON   F   6-28-2011   01-07-2016  Senior Manager
# 45758      LOUISE     ALTARAS   F   1-14-2014   01-07-2016         Analyst
# 47315       RENEE      ALVINO   F   1-23-2014   01-07-2016         Analyst
# 45172        TERI   ANASTASIO   F   3-17-2014   01-07-2016         Analyst
# 49176     GREGORY      ABARCA   M   9-18-2014   01-07-2016         Analyst
#
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#       SALARY FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE  \
# 0      44570     TOMASA       ARMEN   F   5-18-2014   01-07-2016
# 1      89207      ANNIE         NaN   F         NaN   01-07-2016
# 2      40955      OLIVE        ANCY   F   7-28-2014   01-07-2016
# 3      45550     CHERRY     AQUILAR   F  04-03-2013   01-07-2016
# 4      43161       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016
# ...      ...        ...         ...  ..         ...          ...
# 2634  185977  KATHERINE      ALSDON   F   6-28-2011   01-07-2016
# 2635   45758     LOUISE     ALTARAS   F   1-14-2014   01-07-2016
# 2636   47315      RENEE      ALVINO   F   1-23-2014   01-07-2016
# 2637   45172       TERI   ANASTASIO   F   3-17-2014   01-07-2016
# 2638   49176    GREGORY      ABARCA   M   9-18-2014   01-07-2016
#
#          DESIGNATION   AGE        UNIT  LEAVES USED  LEAVES REMAINING  \
# 0            Analyst  21.0     Finance         24.0               6.0
# ...

# %%
df.set_index("SALARY", inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8444\1931381675.py in ?()
# ----> 1 df.set_index("SALARY", inplace = True)
#       2 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['SALARY'] are in the columns"
